# %%
ROOT_DIR = r"C:\Users\rajes\OneDrive\Desktop\DAYUMMMMMMMMM\CNN"

# %%
import os
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
results = model.train(data=os.path.join(ROOT_DIR, "config.yaml"), epochs=100)
# Out:
# New https://pypi.org/project/ultralytics/8.3.2 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.101  Python-3.12.4 torch-2.4.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
# !yolo task=detect mode=predict model=C:/Users/rajes/OneDrive/Desktop/DAYUMMMMMMMMM/CNN/runs/detect/train44/weights/best.pt conf=0.70 source=C:/Users/rajes/OneDrive/Desktop/DAYUMMMMMMMMM/CNN/test
# Out:
# ^C
# Ultralytics YOLOv8.2.101 🚀 Python-3.12.4 torch-2.4.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# Model summary (fused): 168 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/10 C:\Users\rajes\OneDrive\Desktop\DAYUMMMMMMMMM\CNN\test\1a1d11f9-0047-46e5-b5c2-f0ab14e5ca26_jpg.rf.be54d2b47bb7bd4c25fa2b3b0393f333.jpg: 640x640 11 Cows, 8.0ms
# image 2/10 C:\Users\rajes\OneDrive\Desktop\DAYUMMMMMMMMM\CNN\test\1a22f9a1-199b-4145-9598-9853409b4977_jpg.rf.3d89215ad6b0ba62b1efe4661e954498.jpg: 640x640 2 Cows, 8.5ms
# image 3/10 C:\Users\rajes\OneDrive\Desktop\DAYUMMMMMMMMM\CNN\test\1a2aee07-c950-4c03-8e72-96fa0922dcb2_jpg.rf.1dfb16d02d61ed4b4a27083a893ad636.jpg: 640x640 4 Cows, 11.0ms
# image 4/10 C:\Users\rajes\OneDrive\Desktop\DAYUMMMMMMMMM\CNN\test\1a2c4960-2e34-46c5-8e25-5fb909263553_jpg.rf.041617d3bbcc2cc2ad4d40de974e1366.jpg: 640x640 13 Cows, 12.0ms
# ...

# %%
import cv2
import numpy as np
from ultralytics import YOLO

def toggle_fullscreen(window_name):
    current_state = cv2.getWindowProperty(window_name, cv2.WND_PROP_FULLSCREEN)
    cv2.setWindowProperty(window_name, cv2.WND_PROP_FULLSCREEN, 
                          cv2.WINDOW_NORMAL if current_state == cv2.WINDOW_FULLSCREEN else cv2.WINDOW_FULLSCREEN)

def draw_gui_bar(img, window_width):
    bar_height = 30
    cv2.rectangle(img, (0, 0), (window_width, bar_height), (60, 60, 60), -1)
    
    # Draw close button
    button_size = 20
    button_padding = 5
    button_pos = (window_width - button_size - button_padding, button_padding)
    cv2.rectangle(img, button_pos, (button_pos[0] + button_size, button_pos[1] + button_size), (200, 0, 0), -1)
    
    cv2.line(img, (button_pos[0] + 5, button_pos[1] + 5), 
             (button_pos[0] + button_size - 5, button_pos[1] + button_size - 5), (255, 255, 255), 2)
    cv2.line(img, (button_pos[0] + button_size - 5, button_pos[1] + 5), 
             (button_pos[0] + 5, button_pos[1] + button_size - 5), (255, 255, 255), 2)
    
    return bar_height, button_pos, button_size

def is_mouse_over_button(mouse_pos, button_pos, button_size):
    return (button_pos[0] < mouse_pos[0] < button_pos[0] + button_size and
            button_pos[1] < mouse_pos[1] < button_pos[1] + button_size)

model = YOLO('C:/Users/rajes/OneDrive/Desktop/DAYUMMMMMMMMM/CNN/runs/detect/train44/weights/best.pt')

video_path = r"C:\Users\rajes\OneDrive\Desktop\DAYUMMMMMMMMM\CNN\test\videos\stock-footage-aerial-photography-of-cows-dairy-farm-cattle-on-green-field-cow-farm-aerial-photography-of.webm"
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error opening video stream or file")

window_name = 'Video Detection'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.setWindowProperty(window_name, cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

mouse_x, mouse_y = 0, 0
is_mouse_down = False
should_exit = False

def mouse_callback(event, x, y, flags, param):
    global mouse_x, mouse_y, is_mouse_down, should_exit
    mouse_x, mouse_y = x, y
    
    if event == cv2.EVENT_LBUTTONDOWN:
        is_mouse_down = True
    elif event == cv2.EVENT_LBUTTONUP:
        if is_mouse_down and is_mouse_over_button((x, y), close_button_pos, close_button_size):
            should_exit = True
        is_mouse_down = False

cv2.setMouseCallback(window_name, mouse_callback)

screen_width = cv2.getWindowImageRect(window_name)[2]
screen_height = cv2.getWindowImageRect(window_name)[3]

while cap.isOpened() and not should_exit:
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.resize(frame, (screen_width, screen_height))

    results = model(frame)
    annotated_frame = results[0].plot()

    bar_height, close_button_pos, close_button_size = draw_gui_bar(annotated_frame, screen_width)

    if is_mouse_over_button((mouse_x, mouse_y), close_button_pos, close_button_size):
        annotated_frame = cv2.circle(annotated_frame, (mouse_x, mouse_y), 5, (0, 0, 255), -1)
    
    cv2.imshow(window_name, annotated_frame)

    key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):
        break
    elif key == ord('f'):
        toggle_fullscreen(window_name)

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 41 Cows, 9.0ms
# Speed: 4.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 47 Cows, 7.0ms
# Speed: 4.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 Cows, 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 Cows, 8.0ms
# Speed: 3.4ms preprocess, 8.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 Cows, 7.0ms
# Speed: 4.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 Cows, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 Cows, 8.0ms
# Speed: 4.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 Cows, 7.0ms
# ...

# %%
import requests

def get_cities_and_condition():
    """Get the cities and condition from the API"""
    url = "https://quest.squadcast.tech/api/RA2111030010134/weather"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    raise Exception("Failed to get cities and condition")

def get_weather_details(city):
    """Get weather details for a specific city"""
    url = f"https://quest.squadcast.tech/api/RA2111030010134/weather/get?q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    raise Exception(f"Failed to get weather details for {city}")

def find_better_location():
    # Get cities and condition
    data = get_cities_and_condition()
    city1 = data['city1']
    city2 = data['city2']
    condition = data['condition']
    
    # Get weather details for both cities
    weather1 = get_weather_details(city1)
    weather2 = get_weather_details(city2)
    
    # Define comparison logic for each condition
    comparison_rules = {
        'hot': lambda w1, w2: (w1['temp'] > w2['temp'], 'temp'),
        'cold': lambda w1, w2: (w1['temp'] < w2['temp'], 'temp'),
        'windy': lambda w1, w2: (w1['wind'] > w2['wind'], 'wind'),
        'rainy': lambda w1, w2: (w1['rain'] > w2['rain'], 'rain'),
        'sunny': lambda w1, w2: (w1['cloud'] < w2['cloud'], 'cloud'),
        'cloudy': lambda w1, w2: (w1['cloud'] > w2['cloud'], 'cloud')
    }
    
    if condition not in comparison_rules:
        raise ValueError(f"Unknown condition: {condition}")
    
    # Compare the cities based on the condition
    is_city1_better, metric = comparison_rules[condition](weather1, weather2)
    better_city = city1 if is_city1_better else city2
    
    return better_city

def submit_answer(answer):
    """Submit the answer to the API"""
    url = f"https://quest.squadcast.tech/api/RA2111030010134/submit/weather?answer={answer}&extension=py"
    with open(__file__, 'r') as file:
        code = file.read()
    response = requests.post(url, data=code)
    if response.status_code != 200:
        raise Exception("Failed to submit answer")
    return response.json()

if __name__ == "__main__":
    try:
        better_location = find_better_location()
        result = submit_answer(better_location)
        print(f"Better location: {better_location}")
        print(f"Submission result: {result}")
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# Error: Expecting value: line 1 column 1 (char 0)
